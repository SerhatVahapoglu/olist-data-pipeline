# %%
# config/project_config

# 1. CATALOG VE DATABASE AYARLARI (Unity Catalog)
current_catalog = "end_to_end_project"

# Database (Schema) isimlerini belirliyoruz
# Not: Unity Catalog'da yapı: Catalog.Schema.Table şeklindedir.
db_bronze = f"{current_catalog}.olist_bronze"
db_silver = f"{current_catalog}.olist_silver"
db_gold   = f"{current_catalog}.olist_gold"

# 2. DOSYA YOLU (Volume Path)
# Dosyaları 'end_to_end_project' kataloğunda, 'default' şemasında, 'raw_files' volume'üne yüklediysen:
# config/project_config

# DÜZELTME: 'default' yerine 'olist_source' yazmalısın.
raw_data_path = "/Volumes/end_to_end_project/olist_source/raw_files/"

# Geri kalanlar aynen kalsın
print(f"📂 Veri Yolu (Düzeltildi): {raw_data_path}")

# 3. DOSYA LİSTESİ
datasets = {
    "customers": "olist_customers_dataset.csv",
    "geolocation": "olist_geolocation_dataset.csv",
    "order_items": "olist_order_items_dataset.csv",
    "order_payments": "olist_order_payments_dataset.csv",
    "order_reviews": "olist_order_reviews_dataset.csv",
    "orders": "olist_orders_dataset.csv",
    "products": "olist_products_dataset.csv",
    "sellers": "olist_sellers_dataset.csv",
    "category_translation": "product_category_name_translation.csv"
}

print("✅ Project Config Loaded (Unity Catalog Mode)!")
print(f"📂 Veri Yolu: {raw_data_path}")
